# %% [markdown]
# Fetch and store ticker data

# %%
from tickerset import *

# %%
t = TickerSet(use_csv=False)
# Out:
# Pulling Ticker data from Yahoo Finance
# Creating yf Ticker instance for XLF, fetching history
# Creating yf Ticker instance for XHB, fetching history
# Creating yf Ticker instance for XLK, fetching history
# Creating yf Ticker instance for XLY, fetching history
# Creating yf Ticker instance for XLP, fetching history
# Creating yf Ticker instance for XRT, fetching history
# Creating yf Ticker instance for XLI, fetching history
# Creating yf Ticker instance for XLB, fetching history
# Creating yf Ticker instance for XTL, fetching history
# Creating yf Ticker instance for XLU, fetching history
# Creating yf Ticker instance for ^VIX, fetching history
# /Users/murphybre/.local/share/virtualenvs/MADS-M1-analysis-of-price-sensitivity-to-v-hcq5-aJA/lib/python3.8/site-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %%
#view the dataframe
t.df.head()
# Out:
#         date   open   high    low  close  volume  dividends  stock splits  \
# 0 1998-12-22  12.09  12.09  11.97  12.02   55887        0.0           0.0
# 1 1998-12-23  11.97  12.20  11.97  12.20   78784        0.0           0.0
# 2 1998-12-24  12.20  12.28  12.16  12.28   43824        0.0           0.0
# 3 1998-12-28  12.27  12.27  12.09  12.12   51948        0.0           0.0
# 4 1998-12-29  12.13  12.25  11.99  12.25  100819        0.0           0.0
#
#   ticker  vix_open  vix_close  vix_open_minus_thresh  vix_close_minus_thresh
# 0    XLF     24.05      22.78                   6.05                    4.78
# 1    XLF     21.89      20.21                   3.89                    2.21
# 2    XLF     21.00      21.48                   3.00                    3.48
# 3    XLF     22.92      23.50                   4.92                    5.50
# 4    XLF     23.68      22.18                   5.68                    4.18

# %%
t.write_to_csv()

# %% [markdown]
# Create and store aggregate measures

# %%
from aggregations import *

# %%
a = AggregateMeasures(use_csv=False)
# Out:
# Read from csv
# Loading Event Dates
# Read from csv
# Read from csv
# Read from csv
# Read from csv
# Loading Economic Reporting Dates From CSV
# Read from csv
# Adding Event Flag columns to ticker history
# Creating aggregations
# /Users/murphybre/.local/share/virtualenvs/MADS-M1-analysis-of-price-sensitivity-to-v-hcq5-aJA/lib/python3.8/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# /Users/murphybre/.local/share/virtualenvs/MADS-M1-analysis-of-price-sensitivity-to-v-hcq5-aJA/lib/python3.8/site-packages/pandas/core/indexing.py:1773: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
#viw the dataframe 
a.df.head()
# Out:
#   ticker        factor  price_chg_c2c_dir_0  price_chg_c2c_dir_1  \
# 0    XHB  black_friday             0.508112             0.500000
# 1    XLB  black_friday             0.518670             0.583851
# 2    XLF  black_friday             0.505780             0.527950
# 3    XLI  black_friday             0.532183             0.534161
# 4    XLK  black_friday             0.534495             0.552795
#
#    price_chg_o2c_dir_0  price_chg_o2c_dir_1  volume_pchg_from_med_dir_0  \
# 0             0.488540             0.553571                    0.494978
# 1             0.494666             0.546584                    0.501956
# 2             0.490932             0.472050                    0.514905
# 3             0.505156             0.540373                    0.530050
# 4             0.508357             0.527950                    0.509602
#
#    volume_pchg_from_med_dir_1  price_chg_c2o_dir_0  price_chg_c2o_dir_1  ...  \
# 0                    0.392857             0.535926             0.526786  ...
# 1                    0.472050             0.531294             0.515528  ...
# 2                    0.416149             0.513783             0.515528  ...
# 3                    0.422360             0.528805             0.521739  ...
# 4                    0.540373             0.538762             0.559006  ...
#
#    zscore_o2c_mag_0  zscore_o2c_mag_1  zscore_o2c_mag_diff  zscore_c2c_mag_0  \
# 0          0.767759          0.784742             0.016983          0.762029
# 1          0.758062          0.685631            -0.072431          0.718252
# 2          0.743888          0.673345            -0.070543          0.742284
# 3          0.734536          0.712466            -0.022071          0.709266
# 4          0.749875          0.739071            -0.010804          0.714245
#
#    zscore_c2c_mag_1  zscore_c2c_mag_diff  vix_close_minus_thresh_avg_0  \
# 0          0.815457             0.053428                      1.520737
# 1          0.755035             0.036783                      2.127427
# 2          0.807363             0.065079                      2.127427
# 3          0.725887             0.016621                      2.127427
# 4          0.771767             0.057522                      2.127427
#
#    vix_close_minus_thresh_avg_1  vix_open_minus_thresh_avg_0  \
# 0                      2.746875                     1.636330
# 1                      2.573292                     2.253064
# 2                      2.573292                     2.253064
# 3                      2.573292                     2.253064
# 4                      2.573292                     2.253064
#
#    vix_open_minus_thresh_avg_1
# 0                     3.005804
# 1                     2.749503
# 2                     2.749503
# 3                     2.749503
# 4                     2.749503
#
# [5 rows x 35 columns]

# %%
a.write_to_csv()
